# %% [markdown]
# # `Individual` models

# %%
# Sconda conda activate tensorflow2; cd /mnt/BioAdHoc/Groups/RaoLab/Edahi/Projects/09.TimeCourse5hmC/ForFerhatGit/FCDNN/results/deeplift_analysis/; python

# %%
# %load_ext lab_black

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    roc_auc_score,
)

import os

import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Dropout,
)
from tensorflow.keras.initializers import GlorotUniform

from tensorflow.keras.optimizers import Adam
from keras.models import model_from_json
from keras import backend as K

import sys
import pkg_resources
# Out:
# /scratch/ipykernel_3768460/193332328.py:28: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %% [markdown]
# ## Declare some constants

# %%
out_dir = "/mnt/BioAdHoc/Groups/RaoLab/Edahi/Projects/09.TimeCourse5hmC/ForFerhatGit/FCDNN/results/fcdnn_keras_hyperparams_table"
keras_model_json = "./models/clean_samples_model.json"
keras_model_weights = "./models/clean_samples_weights.h5"
OutputLayer = "sigmoid"
data_dir = "/mnt/BioAdHoc/Groups/RaoLab/Edahi/Projects/09.TimeCourse5hmC/ForFerhatGit/FCDNN/data/C2B"
sample_names = pd.read_csv(
    "/mnt/BioAdHoc/Groups/RaoLab/Edahi/Projects/09.TimeCourse5hmC/ForFerhatGit/FCDNN/filtered_files_surnames.csv",
    header=None,
)[7].tolist()

# %% [markdown]
# ### Loading Datasets

# %%
def load_dataset(data_dir, sample, print_shape: bool = False):
    preffix = os.path.join(data_dir, sample)
    X = np.load(preffix + "_Train_X.npz")["arr_0"].T
    Y = np.load(preffix + "_Train_Y.npz")["arr_0"].T
    X_dev = np.load(preffix + "_Dev_X.npz")["arr_0"].T
    Y_dev = np.load(preffix + "_Dev_Y.npz")["arr_0"].T
    X_test = np.load(preffix + "_Test_X.npz")["arr_0"].T
    Y_test = np.load(preffix + "_Test_Y.npz")["arr_0"].T
    if print_shape:
        print(
            f"""
X_train shape: {X.shape}
Y_train shape: {Y.shape}

X_dev shape: {X_dev.shape}
Y_dev shape: {Y_dev.shape}

X_test shape: {X_test.shape}
Y_test shape: {Y_test.shape}
"""
        )
    return X, Y, X_dev, Y_dev, X_test, Y_test

# %% [markdown]
# ## Sequential-style FCDNN

# %% [markdown]
# ### Function to remove layer that is causing issues:

# %%
# Load the original JSON data
def json_remove_input_layer(json_file):
    # Read json
    with open(json_file, "r") as file:
        data = json.load(file)
        file.close()
    # Check if it has the problem and delete
    if (
        data["config"]["layers"]
        and data["config"]["layers"][0]["class_name"] == "InputLayer"
    ):
        del data["config"]["layers"][0]
        print("deleted 'InputLayer' layer config")
        # Save the modified data back to a new JSON file
        with open(json_file, "w") as file:
            json.dump(data, file, indent=4)
            file.close()
    else:
        print("Model does not contain 'InputLayer' in layer config")


# Remove the first layer from the 'layers' list within the 'config' key

# %% [markdown]
# ### Function to make Keras model

# %%
# Helper function to identify layers structure:
# I need to know how many layers to set properly the in and out and the intermediate ones
def id_hidden_layers(layers: list):
    n_hidden = None
    hidden_layers = False
    n_layers = len(layers)
    if n_layers >= 3:
        hidden_layers = True
        n_hidden = n_layers - 2
    return hidden_layers, n_hidden

# %%
# Make this a function to get a cleaner code:
def make_keras_model(X, layers: list):
    keras_model = Sequential()
    hidden_layers, n_hidden = id_hidden_layers(layers)
    layer_name = 1
    # Input layer
    keras_model.add(
        Dense(
            int(layers[0]),
            activation="relu",
            name=str(layer_name),
            input_dim=X.shape[1],
            kernel_initializer=GlorotUniform(),
        )
    )
    keras_model.add(Dropout(0.15))
    layer_name += 1

    # Hidden Layer(s)
    if hidden_layers:
        for l in range(n_hidden):
            keras_model.add(
                Dense(
                    int(layers[l + 1]),
                    activation="relu",
                    name=str(layer_name),
                    kernel_initializer=GlorotUniform(),
                )
            )
            keras_model.add(Dropout(0.15))
            layer_name += 1

    # Output layer
    keras_model.add(
        Dense(
            int(layers[-1]),
            activation="relu",
            name=str(layer_name),
            kernel_initializer=GlorotUniform(),
        )
    )
    keras_model.add(
        Dense(
            1, activation="sigmoid", name="Output", kernel_initializer=GlorotUniform()
        )
    )
    keras_model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss="binary_crossentropy",
        metrics=["accuracy"],
    )
    return keras_model

# %% [markdown]
# ### Function to test model

# %%
def test_and_auc(
    keras_model,
    X_test,
    Y_test,
):

    ProbableValues = keras_model.predict(X_test)
    Obs = pd.Series(Y_test.flatten().astype(int))
    Prob = pd.Series(ProbableValues.flatten().astype(float))
    auc_score = round(roc_auc_score(Obs, Prob), 4)

    return auc_score

# %% [markdown]
# ### Declare layers and results dict

# %%
layers_set = [
    [200, 100, 50],
    [100, 100, 100],
    [50, 50, 50],
    [200, 200],
    [100, 100],
    [50, 50],
]

auc_results = dict()
for i in range(len(layers_set)):
    auc_results[i] = []

# %% [markdown]
# ### Train Models

# %%
for i, sample in enumerate(sample_names):
    # load data:
    print(sample)
    X, Y, X_dev, Y_dev, X_test, Y_test = load_dataset(data_dir, sample)
    # Iterate over the layers:
    for l in range(len(layers_set)):
        print(l)
        layers = layers_set[l]
        # clean session
        K.clear_session()
        # define the keras model
        sample_model = make_keras_model(X, layers)
        sample_model.fit(x=X, y=Y, batch_size=1024, epochs=40, verbose=0)
        auc_results[l].append(test_and_auc(sample_model, X_test, Y_test))
# Out:
# mm10_Bcell_Activated_24_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Bcell_Activated_48_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Bcell_Activated_72_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Bcell_Resting_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Bergmann_Glia_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_CD4_Naive_Tcell_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_CD4_SinglePositive_Tcell_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_CD8_Naive_Tcell_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_CD8_SinglePositive_Tcell_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Cardiomyocites_Adult_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Cardiomyocites_TAC_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Colon_Epithelia_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_DoublePositive_Tcell_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_E13_Frontal_Cortex_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_E14_mESC_Rep3
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Female_Cerebellum_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Female_Cortex_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Female_Hippocampus_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Female_Hypothalamus_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Female_Thalamus_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Granule_Cells_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Hematopo_CommonMyeloydProgenitor_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Hematopo_Granulocyte_Monocyte_Progenitor_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Hematopo_LSK_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Hematopo_Megakaryocitic_Erythroyd_Progenitor_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Hematopoietic_Stem_Cells_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Intestinal_Epithelial_Sox_High_Rep3
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Leukemia_Granulocyte_Monocyte_Progenitor_Rep5
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Leukemia_Multipotent_Progenitors_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Liver_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_MEF_Rep3
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Male_Cerebellum_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Male_Cortex_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Male_Hippocampus_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Male_Hypothalamus_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Male_Thalamus_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Myeloid_Progenitors_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Naive_T_Cell_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_P70_10weeks_Frontal_Cortex_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Purkinje_Cells_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Regulatory_T_Cell_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_Th2_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_V6.5_mESC_12h_wAA_2i_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_V6.5_mESC_Rep10
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_WholeBrain_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_iNK_T_Cell_Rep2
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_pre_iPSC_Day00_wDMSO_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_pre_iPSC_Day02_wAA_2i_Rep1
# 0
# 1
# 2
# 3
# 4
# 5
# mm10_pre_iPSC_Day10_wAA_2i_Rep2
# 0
# 1
# 2
# 3
# 4
# 5

# %%
column_names = []
for l in range(len(layers_set)):
    column_names.append("_".join(map(str, layers_set[l])))

# %%
auc_per_layer_conf = pd.DataFrame(auc_results)
auc_per_layer_conf.columns = column_names
auc_per_layer_conf.index = sample_names
auc_per_layer_conf
# Out:
#                                                     200_100_50  100_100_100  \
# mm10_Bcell_Activated_24_Rep1                            0.8994       0.9027
# mm10_Bcell_Activated_48_Rep1                            0.9047       0.9063
# mm10_Bcell_Activated_72_Rep1                            0.8896       0.8858
# mm10_Bcell_Resting_Rep1                                 0.9076       0.9003
# mm10_Bergmann_Glia_Rep2                                 0.8328       0.8208
# mm10_CD4_Naive_Tcell_Rep2                               0.9298       0.9318
# mm10_CD4_SinglePositive_Tcell_Rep1                      0.9095       0.8992
# mm10_CD8_Naive_Tcell_Rep2                               0.9321       0.9286
# mm10_CD8_SinglePositive_Tcell_Rep2                      0.9293       0.9253
# mm10_Cardiomyocites_Adult_Rep1                          0.7955       0.7926
# mm10_Cardiomyocites_TAC_Rep2                            0.7539       0.7495
# mm10_Colon_Epithelia_Rep2                               0.9051       0.9057
# mm10_DoublePositive_Tcell_Rep2                          0.8802       0.8839
# mm10_E13_Frontal_Cortex_Rep1                            0.8265       0.8107
# mm10_E14_mESC_Rep3                                      0.8058       0.8108
# mm10_Female_Cerebellum_Rep1                             0.8426       0.8425
# mm10_Female_Cortex_Rep1                                 0.8510       0.8405
# mm10_Female_Hippocampus_Rep1                            0.8380       0.8422
# mm10_Female_Hypothalamus_Rep1                           0.8531       0.8547
# mm10_Female_Thalamus_Rep1                               0.8460       0.8465
# mm10_Granule_Cells_Rep1                                 0.8791       0.8738
# mm10_Hematopo_CommonMyeloydProgenitor_Rep1              0.8559       0.8534
# mm10_Hematopo_Granulocyte_Monocyte_Progenitor_Rep1      0.8383       0.8341
# mm10_Hematopo_LSK_Rep1                                  0.8523       0.8480
# mm10_Hematopo_Megakaryocitic_Erythroyd_Progenit...      0.8490       0.8595
# mm10_Hematopoietic_Stem_Cells_Rep1                      0.8547       0.8460
# mm10_Intestinal_Epithelial_Sox_High_Rep3                0.8812       0.8800
# mm10_Leukemia_Granulocyte_Monocyte_Progenitor_Rep5      0.8232       0.8257
# mm10_Leukemia_Multipotent_Progenitors_Rep2              0.8310       0.8273
# mm10_Liver_Rep1                                         0.8864       0.8869
# mm10_MEF_Rep3                                           0.7948       0.7950
# mm10_Male_Cerebellum_Rep1                               0.8613       0.8549
# mm10_Male_Cortex_Rep1                                   0.8465       0.8406
# mm10_Male_Hippocampus_Rep1                              0.8077       0.8070
# mm10_Male_Hypothalamus_Rep1                             0.8486       0.8481
# mm10_Male_Thalamus_Rep1                                 0.8504       0.8435
# mm10_Myeloid_Progenitors_Rep1                           0.8447       0.8463
# mm10_Naive_T_Cell_Rep2                                  0.9173       0.9120
# mm10_P70_10weeks_Frontal_Cortex_Rep1                    0.8648       0.8578
# mm10_Purkinje_Cells_Rep1                                0.8629       0.8590
# mm10_Regulatory_T_Cell_Rep2                             0.9203       0.9206
# mm10_Th2_Rep1                                           0.7382       0.7253
# mm10_V6.5_mESC_12h_wAA_2i_Rep1                          0.8600       0.8512
# mm10_V6.5_mESC_Rep10                                    0.8614       0.8546
# mm10_WholeBrain_Rep1                                    0.8400       0.8387
# mm10_iNK_T_Cell_Rep2                                    0.9253       0.9300
# mm10_pre_iPSC_Day00_wDMSO_Rep1                          0.8264       0.8078
# mm10_pre_iPSC_Day02_wAA_2i_Rep1                         0.8761       0.8724
# mm10_pre_iPSC_Day10_wAA_2i_Rep2                         0.8747       0.8664
#
#                                                     50_50_50  200_200  \
# mm10_Bcell_Activated_24_Rep1                          0.8828   0.8978
# mm10_Bcell_Activated_48_Rep1                          0.8978   0.9065
# mm10_Bcell_Activated_72_Rep1                          0.8782   0.8881
# mm10_Bcell_Resting_Rep1                               0.8969   0.9012
# mm10_Bergmann_Glia_Rep2                               0.8182   0.8363
# mm10_CD4_Naive_Tcell_Rep2                             0.9277   0.9266
# mm10_CD4_SinglePositive_Tcell_Rep1                    0.8912   0.9066
# mm10_CD8_Naive_Tcell_Rep2                             0.9325   0.9333
# mm10_CD8_SinglePositive_Tcell_Rep2                    0.9166   0.9303
# mm10_Cardiomyocites_Adult_Rep1                        0.7872   0.7986
# mm10_Cardiomyocites_TAC_Rep2                          0.7273   0.7637
# mm10_Colon_Epithelia_Rep2                             0.9061   0.9007
# mm10_DoublePositive_Tcell_Rep2                        0.8630   0.8869
# mm10_E13_Frontal_Cortex_Rep1                          0.8101   0.8344
# mm10_E14_mESC_Rep3                                    0.7812   0.8058
# mm10_Female_Cerebellum_Rep1                           0.8203   0.8280
# mm10_Female_Cortex_Rep1                               0.8360   0.8423
# mm10_Female_Hippocampus_Rep1                          0.8147   0.8338
# mm10_Female_Hypothalamus_Rep1                         0.8393   0.8332
# mm10_Female_Thalamus_Rep1                             0.8369   0.8589
# mm10_Granule_Cells_Rep1                               0.8729   0.8745
# mm10_Hematopo_CommonMyeloydProgenitor_Rep1            0.8428   0.8487
# mm10_Hematopo_Granulocyte_Monocyte_Progenitor_Rep1    0.8039   0.8424
# mm10_Hematopo_LSK_Rep1                                0.8452   0.8467
# mm10_Hematopo_Megakaryocitic_Erythroyd_Progenit...    0.8418   0.8489
# mm10_Hematopoietic_Stem_Cells_Rep1                    0.8205   0.8512
# mm10_Intestinal_Epithelial_Sox_High_Rep3              0.8639   0.8729
# mm10_Leukemia_Granulocyte_Monocyte_Progenitor_Rep5    0.8120   0.8279
# mm10_Leukemia_Multipotent_Progenitors_Rep2            0.8108   0.8215
# mm10_Liver_Rep1                                       0.8806   0.8875
# mm10_MEF_Rep3                                         0.7725   0.7948
# mm10_Male_Cerebellum_Rep1                             0.8369   0.8589
# mm10_Male_Cortex_Rep1                                 0.8200   0.8393
# mm10_Male_Hippocampus_Rep1                            0.7940   0.8052
# mm10_Male_Hypothalamus_Rep1                           0.8366   0.8506
# mm10_Male_Thalamus_Rep1                               0.8261   0.8468
# mm10_Myeloid_Progenitors_Rep1                         0.8239   0.8422
# mm10_Naive_T_Cell_Rep2                                0.9036   0.9128
# mm10_P70_10weeks_Frontal_Cortex_Rep1                  0.8472   0.8577
# mm10_Purkinje_Cells_Rep1                              0.8525   0.8472
# mm10_Regulatory_T_Cell_Rep2                           0.9138   0.9168
# mm10_Th2_Rep1                                         0.6893   0.7358
# mm10_V6.5_mESC_12h_wAA_2i_Rep1                        0.8475   0.8528
# mm10_V6.5_mESC_Rep10                                  0.8372   0.8530
# mm10_WholeBrain_Rep1                                  0.8365   0.8399
# mm10_iNK_T_Cell_Rep2                                  0.9196   0.9271
# mm10_pre_iPSC_Day00_wDMSO_Rep1                        0.7963   0.8202
# mm10_pre_iPSC_Day02_wAA_2i_Rep1                       0.8450   0.8773
# mm10_pre_iPSC_Day10_wAA_2i_Rep2                       0.8515   0.8726
#
#                                                     100_100   50_50
# mm10_Bcell_Activated_24_Rep1                         0.8884  0.8853
# mm10_Bcell_Activated_48_Rep1                         0.8904  0.8872
# mm10_Bcell_Activated_72_Rep1                         0.8874  0.8801
# mm10_Bcell_Resting_Rep1                              0.9105  0.8866
# mm10_Bergmann_Glia_Rep2                              0.8289  0.7983
# mm10_CD4_Naive_Tcell_Rep2                            0.9224  0.9155
# mm10_CD4_SinglePositive_Tcell_Rep1                   0.9019  0.8948
# mm10_CD8_Naive_Tcell_Rep2                            0.9239  0.9205
# mm10_CD8_SinglePositive_Tcell_Rep2                   0.9229  0.9099
# mm10_Cardiomyocites_Adult_Rep1                       0.7786  0.7556
# mm10_Cardiomyocites_TAC_Rep2                         0.7461  0.7127
# mm10_Colon_Epithelia_Rep2                            0.8985  0.8842
# mm10_DoublePositive_Tcell_Rep2                       0.8683  0.8654
# mm10_E13_Frontal_Cortex_Rep1                         0.8192  0.7998
# mm10_E14_mESC_Rep3                                   0.8059  0.7761
# mm10_Female_Cerebellum_Rep1                          0.8277  0.8108
# mm10_Female_Cortex_Rep1                              0.8397  0.8351
# mm10_Female_Hippocampus_Rep1                         0.8291  0.8282
# mm10_Female_Hypothalamus_Rep1                        0.8483  0.8380
# mm10_Female_Thalamus_Rep1                            0.8408  0.8233
# mm10_Granule_Cells_Rep1                              0.8722  0.8621
# mm10_Hematopo_CommonMyeloydProgenitor_Rep1           0.8504  0.8339
# mm10_Hematopo_Granulocyte_Monocyte_Progenitor_Rep1   0.8270  0.8188
# mm10_Hematopo_LSK_Rep1                               0.8242  0.8360
# mm10_Hematopo_Megakaryocitic_Erythroyd_Progenit...   0.8446  0.8364
# mm10_Hematopoietic_Stem_Cells_Rep1                   0.8360  0.8235
# mm10_Intestinal_Epithelial_Sox_High_Rep3             0.8817  0.8649
# mm10_Leukemia_Granulocyte_Monocyte_Progenitor_Rep5   0.8083  0.7965
# mm10_Leukemia_Multipotent_Progenitors_Rep2           0.8231  0.8222
# mm10_Liver_Rep1                                      0.8942  0.8762
# mm10_MEF_Rep3                                        0.7961  0.7431
# mm10_Male_Cerebellum_Rep1                            0.8460  0.8466
# mm10_Male_Cortex_Rep1                                0.8408  0.8229
# mm10_Male_Hippocampus_Rep1                           0.7963  0.7761
# mm10_Male_Hypothalamus_Rep1                          0.8469  0.8367
# mm10_Male_Thalamus_Rep1                              0.8441  0.8295
# mm10_Myeloid_Progenitors_Rep1                        0.8371  0.8236
# mm10_Naive_T_Cell_Rep2                               0.9095  0.9023
# mm10_P70_10weeks_Frontal_Cortex_Rep1                 0.8499  0.8448
# mm10_Purkinje_Cells_Rep1                             0.8506  0.8353
# mm10_Regulatory_T_Cell_Rep2                          0.9156  0.9165
# mm10_Th2_Rep1                                        0.7255  0.6855
# mm10_V6.5_mESC_12h_wAA_2i_Rep1                       0.8493  0.8322
# mm10_V6.5_mESC_Rep10                                 0.8481  0.8265
# mm10_WholeBrain_Rep1                                 0.8334  0.8220
# mm10_iNK_T_Cell_Rep2                                 0.9283  0.9142
# mm10_pre_iPSC_Day00_wDMSO_Rep1                       0.8002  0.7965
# mm10_pre_iPSC_Day02_wAA_2i_Rep1                      0.8592  0.8523
# mm10_pre_iPSC_Day10_wAA_2i_Rep2                      0.8588  0.8454

# %%
summary_auc = []
for l in auc_per_layer_conf.columns:
    summary_auc.append(
        auc_per_layer_conf[l].describe()[[3, 4, 5, 1, 6, 7]].values.round(4).tolist()
    )
summary_auc
# Out:
# [[0.7382, 0.8383, 0.8547, 0.8593, 0.8864, 0.9321],
#  [0.7253, 0.8387, 0.8534, 0.856, 0.8858, 0.9318],
#  [0.6893, 0.8182, 0.8393, 0.843, 0.8782, 0.9325],
#  [0.7358, 0.8344, 0.8506, 0.8569, 0.8875, 0.9333],
#  [0.7255, 0.8277, 0.8469, 0.8505, 0.8874, 0.9283],
#  [0.6855, 0.822, 0.8353, 0.8373, 0.8762, 0.9205]]

# %%
summary_auc_per_layer = pd.DataFrame(summary_auc)
summary_auc_per_layer.columns = (
    auc_per_layer_conf[l].describe()[[3, 4, 5, 1, 6, 7]].index.tolist()
)
summary_auc_per_layer.index = auc_per_layer_conf.columns
summary_auc_per_layer
# Out:
#                 min     25%     50%    mean     75%     max
# 200_100_50   0.7382  0.8383  0.8547  0.8593  0.8864  0.9321
# 100_100_100  0.7253  0.8387  0.8534  0.8560  0.8858  0.9318
# 50_50_50     0.6893  0.8182  0.8393  0.8430  0.8782  0.9325
# 200_200      0.7358  0.8344  0.8506  0.8569  0.8875  0.9333
# 100_100      0.7255  0.8277  0.8469  0.8505  0.8874  0.9283
# 50_50        0.6855  0.8220  0.8353  0.8373  0.8762  0.9205

# %%
auc_per_layer_conf.to_csv("./distribution_of_auc_per_layer_config.csv")

# %%
summary_auc_per_layer.to_csv("./summary_of_auc_per_layer_config.csv")
